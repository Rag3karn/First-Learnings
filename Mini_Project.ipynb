# %%
#Name-KARN GUPTA
#College-GOVERNMENT COLLAGE OF ENGINEERING, NAGPUR
#Branch-COMPUTER SCIENCE AND ENGINEERING
#Year-2nd Year

# %%
#Dataset-https://raw.githubusercontent.com/ameenmanna8824/DATASETS/main/Mall_Customers.csv
#1.Creating dataframe from the given dataset
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/ameenmanna8824/DATASETS/main/Mall_Customers.csv')
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.size
# Out:
# 1000

# %%
df.nunique()
# Out:
# CustomerID                200
# Genre                       2
# Age                        51
# Annual Income (k$)         64
# Spending Score (1-100)     84
# dtype: int64

# %%
sns.countplot(x='Genre',data=df)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %%
df.Genre.value_counts()
# Out:
# Female    112
# Male       88
# Name: Genre, dtype: int64

# %%
#Group by age
young=np.sum((df['Age']>=0)&(df['Age']<20)) #0 to 19
adult=np.sum((df['Age']>=20)&(df['Age']<40)) #20 to 39
midage=np.sum((df['Age']>=40)&(df['Age']<60)) #40 to 59
old=np.sum(df['Age']>=60) #>=60
print(young,adult,midage,old)
# Out:
# 12 104 64 20

# %%
print(np.min(df['Age']))
print(np.max(df['Age']))
# Out:
# 18
# 70

# %%
plt.plot(df['Annual Income (k$)'],df['Spending Score (1-100)'])

# %%
plt.plot(df['Age'],df["Annual Income (k$)"])
plt.title("AGE vs Annual income")
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.grid()

# %%
plt.plot(df['Annual Income (k$)'],df['Spending Score (1-100)'])
plt.title("Annual income vs Spending Score")
plt.xlabel('Annual income')
plt.ylabel('Spending Score')
plt.grid()

# %%
Annual_income_min=min(df['Annual Income (k$)'].values)
Annual_income_max=max(df['Annual Income (k$)'].values)
Age_min=min(df['Age'].values)
Age_max=max(df['Age'].values)
Annual_income_norm=(df['Annual Income (k$)'].values-Annual_income_min)/(Annual_income_max-Annual_income_min)
Age_norm=(df['Age'].values-Age_min)/(Age_max-Age_min)
plt.plot(Age_norm,Annual_income_norm,color='Red')
plt.xlabel('Age')
plt.ylabel('Annual Income')
plt.grid()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
